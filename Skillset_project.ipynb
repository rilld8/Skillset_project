# %% [markdown]
# First draft of project that parses through Pracuj.pl website in search of skills required for positions related to Data Science.

# %% [markdown]
# First step is to import necessary libraries for reading data and parsing website - urllib and BeautifulSoup. The latter handles all the transformation of nasty, terribly written HTML files and allows displaying it in much more pleasing way. It also provides some great tools for reading data hidden between tags. As it doesn't allow for loading website I will use urllib for that purpose.

# %%
import urllib
from bs4 import BeautifulSoup as bs

# %% [markdown]
# Let's take a look at our website. Firstly I will use urllib to read and load data coming from url into bs4.

# %%
url="http://www.pracuj.pl/praca/data%20science;kw/warszawa;wp"
html=urllib.urlopen(url).read()
soup=bs(html, "html")

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.pracuj.pl/praca/data%20science;kw/warszawa;wp width = 800 height = 300 ></iframe>')
# Out:
# <iframe src=http://www.pracuj.pl/praca/data%20science;kw/warszawa;wp width = 800 height = 300 ></iframe>

# %% [markdown]
# Let's see how our website looks like as a bs4 object.

# %%
len(soup.prettify())
# Out:
# 281588

# %%
print soup.prettify()[90000:120000]
# Out:
#  _list_item_label_input" id="l_12" name="l" type="checkbox" value="12"/>
#             <label class="filters_group_list_item_label" for="l_12">
#              <span>
#               turecki
#              </span>
#              <span class="amount">
#               (0)
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item ">
#             <input class="filters_group_list_item_label_input" id="l_45" name="l" type="checkbox" value="45"/>
#             <label class="filters_group_list_item_label" for="l_45">
#              <span>
#               ukraiński
#              </span>
#              <span class="amount">
#               (0)
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item ">
#             <input class="filters_group_list_item_label_input" id="l_46" name="l" type="checkbox" value="46"/>
#             <label class="filters_group_list_item_label" for="l_46">
#              <span>
#               węgierski
#              </span>
#              <span class="amount">
#               (0)
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item ">
#             <input class="filters_group_list_item_label_input" id="l_28" name="l" type="checkbox" value="28"/>
#             <label class="filters_group_list_item_label" for="l_28">
#              <span>
#               wietnamski
#              </span>
#              <span class="amount">
#               (0)
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item ">
#             <input class="filters_group_list_item_label_input" id="l_51" name="l" type="checkbox" value="51"/>
#             <label class="filters_group_list_item_label" for="l_51">
#              <span>
#               flamandzki
#              </span>
#              <span class="amount">
#               (0)
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item ">
#             <input class="filters_group_list_item_label_input" id="l_52" name="l" type="checkbox" value="52"/>
#             <label class="filters_group_list_item_label" for="l_52">
#              <span>
#               belgijski
#              </span>
#              <span class="amount">
#               (0)
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_showMore more" data-text="Pokaż mniej języków">
#             Pokaż więcej języków
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="block">
#          <div class="filters_group">
#           <div class="filters_group_title acc_btn active">
#            Oferty z okresu
#            <span class="filters_group_title_icon">
#            </span>
#           </div>
#           <ul class="filters_group_list acc_cnt" data-filter="p">
#            <li class="filters_group_list_item">
#             <input class="filters_group_list_item_label_input" id="okres_0" name="p" type="radio" value="-1"/>
#             <label class="filters_group_list_item_label" for="okres_0">
#              <span>
#               Wszystkie
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item">
#             <input class="filters_group_list_item_label_input" id="okres_1" name="p" type="radio" value="1"/>
#             <label class="filters_group_list_item_label" for="okres_1">
#              <span>
#               24h
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item">
#             <input class="filters_group_list_item_label_input" id="okres_2" name="p" type="radio" value="3"/>
#             <label class="filters_group_list_item_label" for="okres_2">
#              <span>
#               3 dni
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item">
#             <input class="filters_group_list_item_label_input" data-test="filtersSevenDays" id="okres_3" name="p" type="radio" value="7"/>
#             <label class="filters_group_list_item_label" for="okres_3">
#              <span>
#               7 dni
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item">
#             <input class="filters_group_list_item_label_input" id="okres_4" name="p" type="radio" value="14"/>
#             <label class="filters_group_list_item_label" for="okres_4">
#              <span>
#               14 dni
#              </span>
#             </label>
#            </li>
#            <li class="filters_group_list_item">
#             <input class="filters_group_list_item_label_input" id="okres_5" name="p" type="radio" value="30"/>
#             <label class="filters_group_list_item_label" for="okres_5">
#              <span>
#               30 dni
#              </span>
#             </label>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="filters_cnt">
#         <input class="filters_cnt_button button button--blue" data-test="filtersBtn" id="zastosuj" onclick="dataLayer.push({ event: 'GAevent', eventCategory: 'Filtrowanie', eventAction: 'Btn_Zastosuj_filtr', eventLabel: 'Wyniki_wyszukiwania_boks_lewa' }); return false" type="submit" value="Zastosuj"/>
#        </div>
#       </div>
#       <div class="leftCol-recomendation" id="SuggestedOffersLeft">
#       </div>
#       <div class="ads-container">
#        <div class="ads-wrapper">
#         <div id="ado-9soAH2MZN3_fvJ2JbkD4PF0iciZmNX4QSLwQGmjMlGv.i7">
#         </div>
#         <div id="ado-woZa4zcQU8GKf2K_J9mCWhwQUR0OkSbnS2ItEtcvSYz.d7">
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="offer rightCol" data-returnurl="%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites" id="returnUrl">
#       <ul class="o-list" id="mainOfferList">
#        <li class="o-list_item noLogo" itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="/poznaj-pracodawce/ey%20(dawniej%20ernst%20-x38-%20young),20005393">
#          <ul class="o-list_item_logo_dots">
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#          </ul>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4756161" data-id="4756161" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4756161">
#          <a class="o-list_item_link_name" href="/praca/praktykant-ka-zespol-aktuarialny-warszawa,oferta,4756161" itemprop="title" title="Praca Praktykant/ka - Zespół Aktuarialny">
#           Praktykant/ka - Zespół Aktuarialny
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="/poznaj-pracodawce/ey%20(dawniej%20ernst%20-x38-%20young),20005393" itemprop="name" title="Praca EY (dawniej Ernst &amp; Young)">
#           EY (dawniej Ernst &amp; Young)
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#          <a class="label profilLabel" href="/poznaj-pracodawce/ey%20(dawniej%20ernst%20-x38-%20young),20005393">
#           o firmie
#          </a>
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location coordinates" itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4756161" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="52.233247" data-lng="20.9999259" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text link dotted">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-15
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           Od kandydatów - studentów i absolwentów studiów magisterskich - oczekujemy: Ukończenia studiów wyższych na kierunkach matematyka, fizyka, informatyka, ekonomia/ekonometria, metody ilościowe bądź pokrewne kierunki ścisłe Bardzo dobrych wyników na...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_item noLogo" itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="/poznaj-pracodawce/jcommerce%20s.a.,18801184">
#          <ul class="o-list_item_logo_dots">
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#          </ul>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4758430" data-id="4758430" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4758430">
#          <a class="o-list_item_link_name" href="/praca/business-intelligence-ms-specialist-warszawa,oferta,4758430" itemprop="title" title="Praca Business Intelligence (MS) Specialist">
#           Business Intelligence (MS) Specialist
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="/poznaj-pracodawce/jcommerce%20s.a.,18801184" itemprop="name" title="Praca JCommerce S.A.">
#           JCommerce S.A.
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location " itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4758430" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="" data-lng="" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text ">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-15
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           #mustknow MS SQL Server – b. dobrze Microsoft BI – b. dobrze T-SQL – b. dobrze C# - b. dobrze...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_item noLogo" itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="/poznaj-pracodawce/deutsche%20bank%20polska%20s.a.,3134133">
#          <ul class="o-list_item_logo_dots">
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#          </ul>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4733139" data-id="4733139" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4733139">
#          <a class="o-list_item_link_name" href="/praca/mlodszy-specjalista-ds-przeciwdzialania-naduzyciom-warszawa,oferta,4733139" itemprop="title" title="Praca Młodszy Specjalista ds. Przeciwdziałania Nadużyciom">
#           Młodszy Specjalista ds. Przeciwdziałania Nadużyciom
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="/poznaj-pracodawce/deutsche%20bank%20polska%20s.a.,3134133" itemprop="name" title="Praca Deutsche Bank Polska S.A.">
#           Deutsche Bank Polska S.A.
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#          <a class="label profilLabel" href="/poznaj-pracodawce/deutsche%20bank%20polska%20s.a.,3134133">
#           o firmie
#          </a>
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location " itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4733139" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="" data-lng="" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text ">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-14
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           zatrudnienie przez firmę zewnętrzną Czym będziesz się zajmować? Analizą danych i budową raportów w obszarze ryzyka operacyjnego i przeciwdziałania nadużyciom Udziałem w budowie procesów i narzędzi przeciwdziałania i wykrywania nadużyć Udziałem w...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_item noLogo" itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="https://pracodawcy.pracuj.pl/exorigo-upos-sp-z-o-o,18350">
#          <ul class="o-list_item_logo_dots">
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#          </ul>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4732396" data-id="4732396" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4732396">
#          <a class="o-list_item_link_name" href="/praca/programista-aplikacji-bi-warszawa,oferta,4732396" itemprop="title" title="Praca Programista Aplikacji BI">
#           Programista Aplikacji BI
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="https://pracodawcy.pracuj.pl/exorigo-upos-sp-z-o-o,18350" itemprop="name" title="Praca Exorigo - Upos sp.z o.o.">
#           Exorigo - Upos sp.z o.o.
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location " itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4732396" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="" data-lng="" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text ">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-14
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           Od wybranej osoby oczekujemy: Wykształcenia wyższego informatycznego lub ekonomicznego; Udokumentowanego, co najmniej rocznego doświadczenia w obszarze programowania baz danych, Oracle i/lub PostrgreSQL i/lub MS SQL Server; Umiejętności...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_item " itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="https://pracodawcy.pracuj.pl/kmd-poland-sp-z-o-o,157464">
#          <img alt="Praca KMD Poland Sp. z o.o." data-original="//i.pcdn.pl/oferty-loga-firm/wyniki-wyszukiwania/14848.png" itemprop="image" src="..." width="65"/>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4717759" data-id="4717759" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4717759">
#          <a class="o-list_item_link_name" href="/praca/microsoft-bi-developer-warszawa,oferta,4717759" itemprop="title" title="Praca Microsoft BI Developer">
#           Microsoft BI Developer
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="https://pracodawcy.pracuj.pl/kmd-poland-sp-z-o-o,157464" itemprop="name" title="Praca KMD Poland Sp. z o.o.">
#           KMD Poland Sp. z o.o.
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location " itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4717759" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="" data-lng="" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text ">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-14
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           If you want to work in an informal, result-oriented team with the best developers as your colleagues… If you want to develop our Finance BI solutions… If you are open-minded and ready for challenges… If you feel like participating in...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_item " itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="https://pracodawcy.pracuj.pl/itmagination-sp-z-o-o,25129">
#          <img alt="Praca ITMAGINATION Sp. z o.o." data-original="//i.pcdn.pl/oferty-loga-firm/wyniki-wyszukiwania/14487.png" itemprop="image" src="..." width="65"/>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4744292" data-id="4744292" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4744292">
#          <a class="o-list_item_link_name" href="/praca/business-intelligence-consultant-warszawa,oferta,4744292" itemprop="title" title="Praca Business Intelligence Consultant">
#           Business Intelligence Consultant
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="https://pracodawcy.pracuj.pl/itmagination-sp-z-o-o,25129" itemprop="name" title="Praca ITMAGINATION Sp. z o.o.">
#           ITMAGINATION Sp. z o.o.
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location " itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4744292" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="" data-lng="" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text ">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-14
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           Osoba na tym stanowisku będzie odpowiedzialna za: Modelowanie oraz tworzenie hurtowni danych Analizę wymagań biznesowych i projektowanie rozwiązań Business Intelligence Projektowanie oraz implementację procesów ETL Tworzenie kostek OLAP,...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_item noLogo" itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="/poznaj-pracodawce/bank%20bg%c5%bc%20bnp%20paribas,18800072">
#          <ul class="o-list_item_logo_dots">
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#          </ul>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4742891" data-id="4742891" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4742891">
#          <a class="o-list_item_link_name" href="/praca/specjalista-ds-baz-danych-i-analizy-portfela-kredytowego-warszawa,oferta,4742891" itemprop="title" title="Praca Specjalista ds. baz danych i analizy portfela kredytowego">
#           Specjalista ds. baz danych i analizy portfela kredytowego
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="/poznaj-pracodawce/bank%20bg%c5%bc%20bnp%20paribas,18800072" itemprop="name" title="Praca Bank BGŻ BNP Paribas">
#           Bank BGŻ BNP Paribas
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#          <a class="label profilLabel" href="/poznaj-pracodawce/bank%20bg%c5%bc%20bnp%20paribas,18800072">
#           o firmie
#          </a>
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location " itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4742891" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="" data-lng="" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text ">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-14
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           WYZWANIA, KTÓRE NA CIEBIE CZEKAJĄ: raportowanie na potrzeby wewnętrzne i zewnętrzne ryzyka kredytowego, sporządzanie analiz portfela kredytowego banku w celu określenia profilu ryzyka, budowa i rozwój narzędzi raportowo-analitycznych, w...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_item noLogo" itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="/poznaj-pracodawce/bank%20bg%c5%bc%20bnp%20paribas,18800072">
#          <ul class="o-list_item_logo_dots">
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#           <li class="o-list_item_logo_dots_dot">
#           </li>
#          </ul>
#         </a>
#         <span class="o-list_star star " data-href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=Favourites&amp;addFav=4720884" data-id="4720884" data-tooltip="Dodaj do ulubionych" data-tooltip-align="right" data-tooltip-checked="Usuń z ulubionych">
#         </span>
#         <h2 class="o-list_item_link" data-applied-offer-id="4720884">
#          <a class="o-list_item_link_name" href="/praca/starszy-specjalista-ds-analiz-i-statystyki-warszawa,oferta,4720884" itemprop="title" title="Praca Starszy Specjalista ds Analiz i Statystyki">
#           Starszy Specjalista ds Analiz i Statystyki
#          </a>
#         </h2>
#         <h3 class="o-list_item_link" data-offers="list" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
#          <a class="o-list_item_link_emp" href="/poznaj-pracodawce/bank%20bg%c5%bc%20bnp%20paribas,18800072" itemprop="name" title="Praca Bank BGŻ BNP Paribas">
#           Bank BGŻ BNP Paribas
#          </a>
#         </h3>
#         <div class="o-list_item_labels">
#          <a class="label profilLabel" href="/poznaj-pracodawce/bank%20bg%c5%bc%20bnp%20paribas,18800072">
#           o firmie
#          </a>
#         </div>
#         <p class="o-list_item_desc clearfix">
#          <span class="o-list_item_desc_location " itemprop="joblocation" itemscope="" itemtype="http://schema.org/Place">
#           <span class="location_cnt" id="location-4720884" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span class="o-list_item_desc_location_icon">
#            </span>
#            <span class="o-list_item_desc_location_name latlng" data-address="Warszawa, mazowieckie" data-lat="" data-lng="" itemprop="addressRegion">
#             <span class="o-list_item_desc_location_name_text shortened-text ">
#              Warszawa, mazowieckie
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="o-list_item_desc_date" itemprop="datePosted">
#           2016-08-14
#          </span>
#         </p>
#         <div class="o-list_item_text">
#          <span class="o-list_item_text_arrow acc_btn">
#          </span>
#          <p class="o-list_item_text_details clearfix acc_cnt">
#           WYZWANIA, KTÓRE NA CIEBIE CZEKAJĄ: analiza, projektowanie i tworzenie infrastruktury analitycznej i raportowej Pionu Operacji w obszarze Personal Finance (bazy danych, ETL, skrypty SAS / SQL), analizy statystyczne miar ilościowych związanych z...
#          </p>
#         </div>
#        </li>
#        <li class="o-list_jobAlert clearfix" data-jobalertcnt="true">
#         <div class="o-list_jobAlert_cnt">
#          <span class="o-list_jobAlert_cnt_icon">
#          </span>
#          <p class="o-list_jobAlert_cnt_title">
#           Chcę otrzymywać podobne oferty pracy na e-mail!
#          </p>
#          <p class="o-list_jobAlert_cnt_text">
#           data science - Warszawa
#          </p>
#         </div>
#         <p class="o-list_jobAlert_btn cnt-btn">
#          <a class="button button--blue" data-btnload="log" data-jobalert="/praca/ajax/createJobAlert?kw=data+science&amp;wp=warszawa&amp;origin=10" data-jobalerthide="true" data-pt="JobAlert##Link_JobAlert_Ustaw##Wyniki_wyszukiwania" href="/logowanie?returnUrl=%2fpraca%2fdata%2520science%3bkw%2fwarszawa%3bwp&amp;emailOriginId=JobAlert&amp;addJa=true">
#           Tak, chcę!
#          </a>
#         </p>
#        </li>
#        <li class="o-list_item " itemscope="" itemtype="http://schema.org/JobPosting">
#         <a class="o-list_item_logo img" href="https://pracodawcy.pracuj.pl/kmd-poland-sp-z-o-o,157464">
#          <img alt="Praca KMD Poland Sp. z o.o." data-original

# %% [markdown]
# So our HTML file has over 280 thousand characters. Links to job offers start around line 100,000th. Each of them is member of class "o-list_item_link_name".

# %% [markdown]
# Let's extract links for each offer that meets our criteria.

# %%
links = soup.find_all('a', class_="o-list_item_link_name")
for link in links[0:10]:
    print link.get('href',)
# Out:
# /praca/praktykant-ka-zespol-aktuarialny-warszawa,oferta,4756161
# /praca/business-intelligence-ms-specialist-warszawa,oferta,4758430
# /praca/mlodszy-specjalista-ds-przeciwdzialania-naduzyciom-warszawa,oferta,4733139
# /praca/programista-aplikacji-bi-warszawa,oferta,4732396
# /praca/microsoft-bi-developer-warszawa,oferta,4717759
# /praca/business-intelligence-consultant-warszawa,oferta,4744292
# /praca/specjalista-ds-baz-danych-i-analizy-portfela-kredytowego-warszawa,oferta,4742891
# /praca/starszy-specjalista-ds-analiz-i-statystyki-warszawa,oferta,4720884
# /praca/bi-development-team-lead-warszawa,oferta,4717565
# /praca/etl-specialist-warszawa,oferta,4740993

# %% [markdown]
# We have links for each offer but it would be nice to know these offers by job title, as advertised by employer.

# %%
job_titles = soup.find_all('a', class_="o-list_item_link_name")
for title in job_titles[0:10]:
    print title.contents[0].strip()
# Out:
# Praktykant/ka - Zespół Aktuarialny
# Business Intelligence (MS) Specialist
# Młodszy Specjalista ds. Przeciwdziałania Nadużyciom
# Programista Aplikacji BI
# Microsoft BI Developer
# Business Intelligence Consultant
# Specjalista ds. baz danych i analizy portfela kredytowego
# Starszy Specjalista ds Analiz i Statystyki
# BI Development Team Lead
# ETL Specialist

# %%
prefix = "www.pracuj.pl"

# %%
links = soup.find_all('a', class_="o-list_item_link_name")
for link in links[0:10]:
    print prefix + link.get('href',)
# Out:
# www.pracuj.pl/praca/praktykant-ka-zespol-aktuarialny-warszawa,oferta,4756161
# www.pracuj.pl/praca/business-intelligence-ms-specialist-warszawa,oferta,4758430
# www.pracuj.pl/praca/mlodszy-specjalista-ds-przeciwdzialania-naduzyciom-warszawa,oferta,4733139
# www.pracuj.pl/praca/programista-aplikacji-bi-warszawa,oferta,4732396
# www.pracuj.pl/praca/microsoft-bi-developer-warszawa,oferta,4717759
# www.pracuj.pl/praca/business-intelligence-consultant-warszawa,oferta,4744292
# www.pracuj.pl/praca/specjalista-ds-baz-danych-i-analizy-portfela-kredytowego-warszawa,oferta,4742891
# www.pracuj.pl/praca/starszy-specjalista-ds-analiz-i-statystyki-warszawa,oferta,4720884
# www.pracuj.pl/praca/bi-development-team-lead-warszawa,oferta,4717565
# www.pracuj.pl/praca/etl-specialist-warszawa,oferta,4740993

# %% [markdown]
# To combine both job ad link and corresponding title I will create dictionary with links as keys.

# %%
job_offers = {}
for link in links:
    job_offers[link.get('href')]={}

# %% [markdown]
# Now for each link I will create additional dictionary that will contain link to given job offer as well as job title.

# %%
for link in links:
    job_offers[link.get('href')]["link"]=prefix + link.get('href')

# %%
for i, link in enumerate(links):
    job_titles = soup.find_all('a', class_="o-list_item_link_name")
    job_offers[link.get('href')]["Job_Title"] = job_titles[i].contents[0].strip()

# %% [markdown]
# Let's take a look at results. We should have job title with link pointing to ad with the offer.

# %%
for key in job_offers.keys():
    print job_offers[key]["Job_Title"] + "\n" + job_offers[key]["link"] + "\n"
# Out:
# Junior Business Intelligence Analyst
# www.pracuj.pl/praca/junior-business-intelligence-analyst-warszawa,oferta,4734392
#
# Specjalista ds. CRM Analitycznego
# www.pracuj.pl/praca/specjalista-ds-crm-analitycznego-warszawa,oferta,4733798
#
# Specjalista ds. rozwoju systemu raportowego
# www.pracuj.pl/praca/specjalista-ds-rozwoju-systemu-raportowego-warszawa,oferta,4747572
#
# Inżynier - Text Mining / Data Mining / Knowledge Engineering
# www.pracuj.pl/praca/inzynier-text-mining-data-mining-knowledge-engineering-warszawa,oferta,4744875
#
# Specjalista ds. E-commerce
# www.pracuj.pl/praca/specjalista-ds-e-commerce-warszawa,oferta,4720582
#
# ETL Specialist
# www.pracuj.pl/praca/etl-specialist-warszawa,oferta,4740993
#
# Business Intelligence (MS) Specialist
# www.pracuj.pl/praca/business-intelligence-ms-specialist-warszawa,oferta,4758430
#
# Tableau Specialist
# www.pracuj.pl/praca/tableau-specialist-warszawa,oferta,4714214
#
# Big Data Architect
# www.pracuj.pl/praca/big-data-architect-warszawa,oferta,4732261
#
# Big Data Technical Lead
# www.pracuj.pl/praca/big-data-technical-lead-warszawa,oferta,4728757
#
# Senior Data Scientist
# www.pracuj.pl/praca/senior-data-scientist-warszawa,oferta,4756059
#
# Reporting Analyst
# www.pracuj.pl/praca/reporting-analyst-warszawa,oferta,4746416
#
# Data Science Architect
# www.pracuj.pl/praca/data-science-architect-warszawa,oferta,4729219
#
# Business Analyst
# www.pracuj.pl/praca/business-analyst-warszawa,oferta,4731622
#
# Programista Java & Cloud w zespole Big Data & Cloud
# www.pracuj.pl/praca/programista-java-cloud-w-zespole-big-data-cloud-warszawa,oferta,4723744
#
# Business Intelligence Consultant
# www.pracuj.pl/praca/business-intelligence-consultant-warszawa,oferta,4750547
#
# Ekspert ds. Hurtowni Danych
# www.pracuj.pl/praca/ekspert-ds-hurtowni-danych-warszawa,oferta,4727789
#
# Młodszy Specjalista ds. Sprzedaży
# www.pracuj.pl/praca/mlodszy-specjalista-ds-sprzedazy-warszawa,oferta,4758757
#
# Architekt - Programista DWH/BI
# www.pracuj.pl/praca/architekt-programista-dwh-bi-warszawa,oferta,4717792
#
# ETL Developer - SSIS
# www.pracuj.pl/praca/etl-developer-ssis-warszawa,oferta,4720245
#
# Młodszy Analityk BI (SQL Server / Reporting Services)
# www.pracuj.pl/praca/mlodszy-analityk-bi-sql-server-reporting-services-warszawa,oferta,4712088
#
# Business Intelligence Consultant
# www.pracuj.pl/praca/business-intelligence-consultant-warszawa,oferta,4744292
#
# CRM Project Manager
# www.pracuj.pl/praca/crm-project-manager-warszawa,oferta,4753896
#
# BI Development Team Lead
# www.pracuj.pl/praca/bi-development-team-lead-warszawa,oferta,4717565
#
# Specjalista ds. Business Intelligence
# www.pracuj.pl/praca/specjalista-ds-business-intelligence-warszawa,oferta,4742520
#
# Dyrektor ds. Rozwoju Projektów Internetowych
# www.pracuj.pl/praca/dyrektor-ds-rozwoju-projektow-internetowych-warszawa,oferta,4755662
#
# Scala Developer
# www.pracuj.pl/praca/scala-developer-warszawa,oferta,4706894
#
# Junior Big Data Engineer
# www.pracuj.pl/praca/junior-big-data-engineer-warszawa,oferta,4757332
#
# Data Analyst - Statistician
# www.pracuj.pl/praca/data-analyst-statistician-warszawa,oferta,4742126
#
# Programista Aplikacji BI
# www.pracuj.pl/praca/programista-aplikacji-bi-warszawa,oferta,4732396
#
# Ekspert ds. modeli ryzyka kredytowego i predictive analytics
# www.pracuj.pl/praca/ekspert-ds-modeli-ryzyka-kredytowego-i-predictive-analytics-warszawa,oferta,4755350
#
# Inżynier – Big Data / Cloud Computing / Knowledge Discovery
# www.pracuj.pl/praca/inzynier-big-data-cloud-computing-knowledge-discovery-warszawa,oferta,4744888
#
# Analityk Systemowy IT
# www.pracuj.pl/praca/analityk-systemowy-it-warszawa,oferta,4717806
#
# Specjalista w Departamencie Zarządzania Ryzykiem Kredytowym
# www.pracuj.pl/praca/specjalista-w-departamencie-zarzadzania-ryzykiem-kredytowym-warszawa,oferta,4747692
#
# Big Data DevOps Engineer
# www.pracuj.pl/praca/big-data-devops-engineer-warszawa,oferta,4716740
#
# Marketing Systems Project Manager
# www.pracuj.pl/praca/marketing-systems-project-manager-warszawa,oferta,4753948
#
# Junior Business Intelligence Engineer
# www.pracuj.pl/praca/junior-business-intelligence-engineer-warszawa,oferta,4741501
#
# Starszy Programista - Techniczny lider zespołu Big Data & Cloud
# www.pracuj.pl/praca/starszy-programista-techniczny-lider-zespolu-big-data-cloud-warszawa,oferta,4723749
#
# Microsoft BI Developer
# www.pracuj.pl/praca/microsoft-bi-developer-warszawa,oferta,4717759
#
# Specjalista ds. baz danych i analizy portfela kredytowego
# www.pracuj.pl/praca/specjalista-ds-baz-danych-i-analizy-portfela-kredytowego-warszawa,oferta,4742891
#
# Big Data Architect - remote working
# www.pracuj.pl/praca/big-data-architect-remote-working-warszawa,oferta,4758813
#
# Specjalista ETL
# www.pracuj.pl/praca/specjalista-etl-warszawa,oferta,4750634
#
# Projektant - Programista Essbase
# www.pracuj.pl/praca/projektant-programista-essbase-warszawa,oferta,4755335
#
# Praktykant/ka - Zespół Aktuarialny
# www.pracuj.pl/praca/praktykant-ka-zespol-aktuarialny-warszawa,oferta,4756161
#
# Starszy Specjalista ds Analiz i Statystyki
# www.pracuj.pl/praca/starszy-specjalista-ds-analiz-i-statystyki-warszawa,oferta,4720884
#
# Programista Pasjonat do zadań specjalnych
# www.pracuj.pl/praca/programista-pasjonat-do-zadan-specjalnych-warszawa,oferta,4744857
#
# Big Data Engineer
# www.pracuj.pl/praca/big-data-engineer-warszawa,oferta,4757458
#
# BI and Reporting Analyst
# www.pracuj.pl/praca/bi-and-reporting-analyst-warszawa,oferta,4755926
#
# Data Analyst
# www.pracuj.pl/praca/data-analyst-warszawa,oferta,4723768
#
# Młodszy Specjalista ds. Przeciwdziałania Nadużyciom
# www.pracuj.pl/praca/mlodszy-specjalista-ds-przeciwdzialania-naduzyciom-warszawa,oferta,4733139

# %% [markdown]
# I will want to save this data to a file as I will use it later on for further analysis. JSON files are easy to parse through and fast to write and read. So let's make use of json library.

# %%
import json
with open("job_offers.json", "w") as writeJSON:
    json.dump(job_offers, writeJSON)
